# %%
# !python train_model.py
# Out:
# Index(['Student_ID', 'Gender', 'Study_Hours', 'Previous_Score', 'Absences',
#        'Attendance', 'Parental_Education', 'Internet_Access',
#        'Extracurricular', 'Final_Grade'],
#       dtype='object')
#    Student_ID  Gender  Study_Hours  ...  Internet_Access  Extracurricular  Final_Grade
# 0           1    Male            2  ...              Yes              Yes           60
# 1           2  Female            4  ...              Yes               No           72
# 2           3    Male            5  ...              Yes              Yes           78
# 3           4  Female            3  ...               No               No           65
# 4           5    Male            6  ...              Yes              Yes           85
#
# [5 rows x 10 columns]
# Result
# 0    17
# 1    13
# Name: count, dtype: int64
# count    30.000000
# mean     77.133333
# std      11.300697
# min      55.000000
# 25%      70.250000
# 50%      77.500000
# 75%      85.750000
# max      96.000000
# ...
